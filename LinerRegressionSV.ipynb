# %%
import pandas as pd
from sklearn import linear_model
import seaborn as sns

# %%
df = pd.read_excel(r"D:\Data_Science\Insurance.xlsx")

# %%
df
# Out:
#    age  premium
# 0   25    18000
# 1   30    32000
# 2   35    40000
# 3   40    47000
# 4   45    55000

# %%
sns.lmplot(x='age',y='premium',data=df)

# %%
reg=linear_model.LinearRegression()

# %%
reg.fit(df[['age']],df[['premium']])
# Out:
# LinearRegression()

# %%
reg.predict([[21]])
# Out:
# C:\Users\sudhanshu ranjan\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[13480.]])

# %%
reg.predict([[55]])
# Out:
# C:\Users\sudhanshu ranjan\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[74000.]])

# %%
reg.coef_
# Out:
# array([[1780.]])

# %%
reg.intercept_
# Out:
# array([-23900.])
