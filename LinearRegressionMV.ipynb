# %%
import pandas as pd
from sklearn import linear_model

# %%
df = pd.read_excel(r"D:\Data_Science\Insurance2.xlsx")

# %%
df
# Out:
#    age  height  weight  premium
# 0   25  162.56      70    18000
# 1   30  172.72      95    38000
# 2   35  167.64      79    38000
# 3   40     NaN     110    60000
# 4   45  157.48      85    70000

# %%
mean_height=df.height.mean()

# %%
df.height=df.height.fillna(mean_height)

# %%
df
# Out:
#    age  height  weight  premium
# 0   25  162.56      70    18000
# 1   30  172.72      95    38000
# 2   35  167.64      79    38000
# 3   40  165.10     110    60000
# 4   45  157.48      85    70000

# %%
reg=linear_model.LinearRegression()

# %%
reg.fit(df[['age','height','weight']],df['premium'])
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([2143.45603859, -261.23120069,  315.16682938])

# %%
reg.intercept_
# Out:
# -14763.337736174064

# %%
reg.predict([[27,167.65,78]])
# Out:
# C:\Users\sudhanshu ranjan\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([23897.57720157])
