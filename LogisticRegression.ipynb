# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel(r"D:\Data_Science\InsuranceLR.xlsx")

# %%
df
# Out:
#     age bought_insurance
# 0    21               no
# 1    45              yes
# 2    32              yes
# 3    41              yes
# 4    20               no
# 5    35              yes
# 6    20               no
# 7    23               no
# 8    42              yes
# 9    34              yes
# 10   24               no
# 11   22               no
# 12   23               no
# 13   25               no
# 14   55              yes
# 15   45              yes

# %%
#categorical data convert into binary data
df['bought_insurance'].replace({'no':'0','yes':'1'},inplace=True)

# %%
df
# Out:
#     age bought_insurance
# 0    21                0
# 1    45                1
# 2    32                1
# 3    41                1
# 4    20                0
# 5    35                1
# 6    20                0
# 7    23                0
# 8    42                1
# 9    34                1
# 10   24                0
# 11   22                0
# 12   23                0
# 13   25                0
# 14   55                1
# 15   45                1

# %%
plt.scatter(x='age',y='bought_insurance',data=df)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test =train_test_split(df[['age']],df['bought_insurance'],test_size=0.2)

# %%
len(X_train)
# Out:
# 12

# %%
len(X_test)
# Out:
# 4

# %%
X_test
# Out:
#    age
# 8   42
# 9   34
# 6   20
# 1   45

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
lr.predict(X_test)
# Out:
# array(['1', '1', '0', '1'], dtype=object)
